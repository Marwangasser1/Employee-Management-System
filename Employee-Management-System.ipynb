# %%
import pandas as pd

# قراءة ملف Excel
#excel_file = "employees.xlsx"
#data = pd.read_excel(excel_file)

# تحويله إلى CSV
#csv_file = "employees.csv"
#data.to_csv(csv_file, index=False)
#print("تم تحويل الملف إلى CSV.")

# %%
import csv

class Employee:
    def __init__(self, emp_id, name, position, salary, email):
        self.emp_id = emp_id.strip()
        self.name = name.strip()
        self.position = position.strip()
        self.salary = float(salary)
        self.email = email.strip()

    def update_details(self, name=None, position=None, salary=None, email=None):
        if name:
            self.name = name.strip()
        if position:
            self.position = position.strip()
        if salary:
            self.salary = float(salary)
        if email:
            self.email = email.strip()

class EmployeeManager:
    def __init__(self, file_name):
        self.file_name = file_name
        self.employees = self.load_data()

    def load_data(self):
        try:
            with open(self.file_name, mode='r') as file:
                reader = csv.DictReader(file)
                return [Employee(row["ID"], row["Name"], row["Position"], row["Salary"], row["Email"]) for row in reader]
        except FileNotFoundError:
            return []

    def save_data(self):
        with open(self.file_name, mode='w', newline='') as file:
            fieldnames = ["ID", "Name", "Position", "Salary", "Email"]
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writeheader()
            for emp in self.employees:
                writer.writerow({
                    "ID": emp.emp_id,
                    "Name": emp.name,
                    "Position": emp.position,
                    "Salary": emp.salary,
                    "Email": emp.email
                })

    def add_employee(self, emp_id, name, position, salary, email):
        if any(str(emp.emp_id) == str(emp_id) for emp in self.employees):
            print(f"Error: Employee ID {emp_id} already exists!")
            return
        new_employee = Employee(emp_id, name, position, salary, email)
        self.employees.append(new_employee)
        self.save_data()
        print("Employee added successfully.")

    def update_employee(self, emp_id, name=None, position=None, salary=None, email=None):
        for emp in self.employees:
            if str(emp.emp_id) == str(emp_id):
                emp.update_details(name, position, salary, email)
                self.save_data()
                print("Employee updated successfully.")
                return
        print(f"Error: Employee ID {emp_id} not found!")

    def delete_employee(self, emp_id):
        for emp in self.employees:
            if str(emp.emp_id) == str(emp_id):
                self.employees.remove(emp)
                self.save_data()
                print("Employee deleted successfully.")
                return
        print(f"Error: Employee ID {emp_id} not found!")

    def search_employee(self, emp_id):
        for emp in self.employees:
            if str(emp.emp_id) == str(emp_id):
                print(f"ID: {emp.emp_id}, Name: {emp.name}, Position: {emp.position}, Salary: {emp.salary}, Email: {emp.email}")
                return
        print(f"Error: Employee ID {emp_id} not found!")

    def list_employees(self):
        if not self.employees:
            print("No employees found.")
        else:
            print("\n--- Employee List ---")
            for emp in self.employees:
                print(f"ID: {emp.emp_id}, Name: {emp.name}, Position: {emp.position}, Salary: {emp.salary}, Email: {emp.email}")

def menu():
    manager = EmployeeManager("employees_sample.csv")
    while True:
        print("\n--- Employee Management System ---")
        print("1. Add Employee")
        print("2. Update Employee")
        print("3. Delete Employee")
        print("4. Search Employee")
        print("5. List Employees")
        print("6. Exit")
        choice = input("Enter your choice (1-6): ")

        if choice == '1':
            emp_id = input("Enter ID: ")
            name = input("Enter Name: ")
            position = input("Enter Position: ")
            salary = input("Enter Salary: ")
            email = input("Enter Email: ")
            manager.add_employee(emp_id, name, position, salary, email)
        elif choice == '2':
            emp_id = input("Enter ID of the employee to update: ")
            name = input("Enter new Name (or leave blank): ")
            position = input("Enter new Position (or leave blank): ")
            salary = input("Enter new Salary (or leave blank): ")
            email = input("Enter new Email (or leave blank): ")
            manager.update_employee(emp_id, name, position, salary, email)
        elif choice == '3':
            emp_id = input("Enter ID of the employee to delete: ")
            manager.delete_employee(emp_id)
        elif choice == '4':
            emp_id = input("Enter ID of the employee to search: ")
            manager.search_employee(emp_id)
        elif choice == '5':
            manager.list_employees()
        elif choice == '6':
            print("Exiting the program. Goodbye!")
            break
        else:
            print("Invalid choice. Please try again.")

# Run the program
if __name__ == "__main__":
    menu()
# Out:
# --- Employee Management System ---
# 1. Add Employee
# 2. Update Employee
# 3. Delete Employee
# 4. Search Employee
# 5. List Employees
# 6. Exit
# Enter your choice (1-6): 1
# Enter ID: 202
# Enter Name: marwan
# Enter Position: manger
# Enter Salary: 9999999999999999999999
# Enter Email: marwangasser@gmail.com
# Employee added successfully.
#
# --- Employee Management System ---
# 1. Add Employee
# 2. Update Employee
# 3. Delete Employee
# 4. Search Employee
# 5. List Employees
# 6. Exit
# Enter your choice (1-6): 50
# Invalid choice. Please try again.
#
# --- Employee Management System ---
# 1. Add Employee
# 2. Update Employee
# 3. Delete Employee
# 4. Search Employee
# 5. List Employees
# 6. Exit
# Enter your choice (1-6): 1
# Enter ID: 50
# Enter Name: marwan
# Enter Position: marwan
# Enter Salary: 5000000
# Enter Email: marwan@gmail.com
# Error: Employee ID 50 already exists!
#
# --- Employee Management System ---
# 1. Add Employee
# 2. Update Employee
# 3. Delete Employee
# 4. Search Employee
# 5. List Employees
# 6. Exit
# Enter your choice (1-6): 2
# Enter ID of the employee to update: 202
# Enter new Name (or leave blank):
# Enter new Position (or leave blank):
# Enter new Salary (or leave blank): 9999999999999999999999999999999999999999
# Enter new Email (or leave blank): marwangasser600000000000000@gmail.com
# Employee updated successfully.
#
# --- Employee Management System ---
# 1. Add Employee
# 2. Update Employee
# 3. Delete Employee
# 4. Search Employee
# 5. List Employees
# 6. Exit
# Enter your choice (1-6): 3
# Enter ID of the employee to delete: 500
# Error: Employee ID 500 not found!
#
# --- Employee Management System ---
# 1. Add Employee
# 2. Update Employee
# 3. Delete Employee
# 4. Search Employee
# 5. List Employees
# 6. Exit
# Enter your choice (1-6): 4
# Enter ID of the employee to search: 202
# ID: 202, Name: marwan, Position: manger, Salary: 1e+40, Email: marwangasser600000000000000@gmail.com
#
# --- Employee Management System ---
# 1. Add Employee
# 2. Update Employee
# 3. Delete Employee
# 4. Search Employee
# 5. List Employees
# 6. Exit
# Enter your choice (1-6): 5
#
# --- Employee List ---
# ID: 1, Name: Mona Shaker, Position: Product Manager, Salary: 14067.0, Email: mona.shaker@example.com
# ID: 2, Name: Khaled Hussein, Position: Graphic Designer, Salary: 11442.0, Email: khaled.hussein@example.com
# ID: 3, Name: Omar Lotfy, Position: Customer Support, Salary: 5926.0, Email: omar.lotfy@example.com
# ID: 4, Name: Mona Farid, Position: Operations Manager, Salary: 4632.0, Email: mona.farid@example.com
# ID: 5, Name: Rami Adel, Position: Business Analyst, Salary: 5289.0, Email: rami.adel@example.com
# ID: 6, Name: Amira Lotfy, Position: Marketing Specialist, Salary: 10018.0, Email: amira.lotfy@example.com
# ID: 7, Name: Khaled Ali, Position: Sales Executive, Salary: 14135.0, Email: khaled.ali@example.com
# ID: 8, Name: Ali Fahmy, Position: HR Manager, Salary: 14451.0, Email: ali.fahmy@example.com
# ID: 9, Name: Ahmed Farid, Position: Content Writer, Salary: 9626.0, Email: ahmed.farid@example.com
# ID: 10, Name: Yasmin Lotfy, Position: Project Manager, Salary: 5947.0, Email: yasmin.lotfy@example.com
# ID: 11, Name: Yasmin Ismail, Position: Project Manager, Salary: 10720.0, Email: yasmin.ismail@example.com
# ID: 12, Name: Ali Shaker, Position: Project Manager, Salary: 4106.0, Email: ali.shaker@example.com
# ID: 13, Name: Salma Sobhy, Position: Data Analyst, Salary: 9863.0, Email: salma.sobhy@example.com
# ID: 14, Name: Mona Hassan, Position: Accountant, Salary: 11381.0, Email: mona.hassan@example.com
# ID: 15, Name: Nora Hussein, Position: Sales Executive, Salary: 8864.0, Email: nora.hussein@example.com
# ID: 16, Name: Laila Shaker, Position: Project Manager, Salary: 12744.0, Email: laila.shaker@example.com
# ID: 17, Name: Sara Fathy, Position: Sales Executive, Salary: 8355.0, Email: sara.fathy@example.com
# ID: 18, Name: Yasmin Othman, Position: Software Engineer, Salary: 14925.0, Email: yasmin.othman@example.com
# ID: 19, Name: Hassan Adel, Position: IT Support, Salary: 4736.0, Email: hassan.adel@example.com
# ID: 20, Name: Huda Hussein, Position: Data Analyst, Salary: 11229.0, Email: huda.hussein@example.com
# ID: 21, Name: Mona Adel, Position: Quality Assurance, Salary: 11080.0, Email: mona.adel@example.com
# ID: 22, Name: Salma Fahmy, Position: Data Analyst, Salary: 12768.0, Email: salma.fahmy@example.com
# ID: 23, Name: Hassan Fahmy, Position: Business Analyst, Salary: 7109.0, Email: hassan.fahmy@example.com
# ID: 24, Name: Mona Sobhy, Position: Data Analyst, Salary: 3642.0, Email: mona.sobhy@example.com
# ID: 25, Name: Sara Kamal, Position: Quality Assurance, Salary: 7833.0, Email: sara.kamal@example.com
# ID: 26, Name: Mohamed Fathy, Position: Sales Executive, Salary: 6486.0, Email: mohamed.fathy@example.com
# ID: 27, Name: Rami Hussein, Position: Marketing Specialist, Salary: 9439.0, Email: rami.hussein@example.com
# ID: 28, Name: Yasmin Hussein, Position: Graphic Designer, Salary: 5778.0, Email: yasmin.hussein@example.com
# ID: 29, Name: Sara Nabil, Position: Business Analyst, Salary: 12642.0, Email: sara.nabil@example.com
# ID: 30, Name: Ali Kamal, Position: Business Analyst, Salary: 14144.0, Email: ali.kamal@example.com
# ID: 31, Name: Amira Nabil, Position: Operations Manager, Salary: 5277.0, Email: amira.nabil@example.com
# ID: 32, Name: Ahmed Ali, Position: Network Administrator, Salary: 6541.0, Email: ahmed.ali@example.com
# ID: 33, Name: Mohamed Fahmy, Position: Software Engineer, Salary: 14789.0, Email: mohamed.fahmy@example.com
# ID: 34, Name: Sara Tawfik, Position: Accountant, Salary: 3358.0, Email: sara.tawfik@example.com
# ID: 35, Name: Huda Sobhy, Position: IT Support, Salary: 11829.0, Email: huda.sobhy@example.com
# ID: 36, Name: Omar Ismail, Position: Accountant, Salary: 4666.0, Email: omar.ismail@example.com
# ID: 37, Name: Ali Othman, Position: Quality Assurance, Salary: 11286.0, Email: ali.othman@example.com
# ID: 38, Name: Nora Kamal, Position: Quality Assurance, Salary: 13400.0, Email: nora.kamal@example.com
# ID: 39, Name: Ahmed Othman, Position: Marketing Specialist, Salary: 14823.0, Email: ahmed.othman@example.com
# ID: 40, Name: Amira Salem, Position: Graphic Designer, Salary: 9622.0, Email: amira.salem@example.com
# ID: 41, Name: Ahmed Nabil, Position: Accountant, Salary: 8598.0, Email: ahmed.nabil@example.com
# ID: 42, Name: Omar Fathy, Position: HR Manager, Salary: 14932.0, Email: omar.fathy@example.com
# ID: 43, Name: Sara Hussein, Position: IT Support, Salary: 6888.0, Email: sara.hussein@example.com
# ID: 44, Name: Yasmin Kamal, Position: Operations Manager, Salary: 12421.0, Email: yasmin.kamal@example.com
# ID: 45, Name: Rami Ismail, Position: Project Manager, Salary: 9417.0, Email: rami.ismail@example.com
# ID: 46, Name: Laila Salem, Position: Data Analyst, Salary: 6799.0, Email: laila.salem@example.com
# ID: 47, Name: Laila Ali, Position: Content Writer, Salary: 12396.0, Email: laila.ali@example.com
# ID: 48, Name: Hassan Adel, Position: Operations Manager, Salary: 11280.0, Email: hassan.adel@example.com
# ID: 49, Name: Khaled Nabil, Position: Accountant, Salary: 7711.0, Email: khaled.nabil@example.com
# ID: 50, Name: Ahmed Hassan, Position: Data Analyst, Salary: 10825.0, Email: ahmed.hassan@example.com
# ID: 51, Name: Tamer Shaker, Position: IT Support, Salary: 12162.0, Email: tamer.shaker@example.com
# ID: 52, Name: Amira Shaker, Position: Quality Assurance, Salary: 5723.0, Email: amira.shaker@example.com
# ID: 53, Name: Ahmed Fahmy, Position: Quality Assurance, Salary: 3135.0, Email: ahmed.fahmy@example.com
# ID: 54, Name: Yasmin Sobhy, Position: Product Manager, Salary: 4551.0, Email: yasmin.sobhy@example.com
# ID: 55, Name: Huda Hassan, Position: Business Analyst, Salary: 5613.0, Email: huda.hassan@example.com
# ID: 56, Name: Mona Othman, Position: Operations Manager, Salary: 6941.0, Email: mona.othman@example.com
# ID: 57, Name: Khaled Othman, Position: Operations Manager, Salary: 8765.0, Email: khaled.othman@example.com
# ID: 58, Name: Huda Ali, Position: Sales Executive, Salary: 9569.0, Email: huda.ali@example.com
# ID: 59, Name: Nora Lotfy, Position: Accountant, Salary: 13949.0, Email: nora.lotfy@example.com
# ID: 60, Name: Huda Ali, Position: Project Manager, Salary: 4799.0, Email: huda.ali@example.com
# ID: 61, Name: Sara Hassan, Position: Software Engineer, Salary: 7279.0, Email: sara.hassan@example.com
# ID: 62, Name: Sara Ismail, Position: Quality Assurance, Salary: 11803.0, Email: sara.ismail@example.com
# ID: 63, Name: Mohamed Shaker, Position: HR Manager, Salary: 3171.0, Email: mohamed.shaker@example.com
# ID: 64, Name: Hassan Hussein, Position: Accountant, Salary: 7833.0, Email: hassan.hussein@example.com
# ID: 65, Name: Omar Ismail, Position: Accountant, Salary: 6762.0, Email: omar.ismail@example.com
# ID: 66, Name: Ahmed Tawfik, Position: Marketing Specialist, Salary: 13894.0, Email: ahmed.tawfik@example.com
# ID: 67, Name: Sara Fahmy, Position: Accountant, Salary: 11152.0, Email: sara.fahmy@example.com
# ID: 68, Name: Laila Hassan, Position: Project Manager, Salary: 10954.0, Email: laila.hassan@example.com
# ID: 69, Name: Ali Hussein, Position: Content Writer, Salary: 13835.0, Email: ali.hussein@example.com
# ID: 70, Name: Ali Nabil, Position: Marketing Specialist, Salary: 10950.0, Email: ali.nabil@example.com
# ID: 71, Name: Salma Tawfik, Position: Accountant, Salary: 6139.0, Email: salma.tawfik@example.com
# ID: 72, Name: Rami Hassan, Position: Graphic Designer, Salary: 13208.0, Email: rami.hassan@example.com
# ID: 73, Name: Hassan Fathy, Position: IT Support, Salary: 11187.0, Email: hassan.fathy@example.com
# ID: 74, Name: Salma Tawfik, Position: Marketing Specialist, Salary: 8262.0, Email: salma.tawfik@example.com
# ID: 75, Name: Huda Tawfik, Position: HR Manager, Salary: 6920.0, Email: huda.tawfik@example.com
# ID: 76, Name: Huda Nabil, Position: Data Analyst, Salary: 7411.0, Email: huda.nabil@example.com
# ID: 77, Name: Yasmin Hassan, Position: Business Analyst, Salary: 3549.0, Email: yasmin.hassan@example.com
# ID: 78, Name: Laila Adel, Position: Graphic Designer, Salary: 14556.0, Email: laila.adel@example.com
# ID: 79, Name: Khaled Hussein, Position: Operations Manager, Salary: 3672.0, Email: khaled.hussein@example.com
# ID: 80, Name: Yasmin Lotfy, Position: Software Engineer, Salary: 7970.0, Email: yasmin.lotfy@example.com
# ID: 81, Name: Tamer Lotfy, Position: Marketing Specialist, Salary: 13280.0, Email: tamer.lotfy@example.com
# ID: 82, Name: Omar Nabil, Position: Network Administrator, Salary: 9103.0, Email: omar.nabil@example.com
# ID: 83, Name: Tamer Shaker, Position: Accountant, Salary: 11383.0, Email: tamer.shaker@example.com
# ID: 84, Name: Hassan Shaker, Position: IT Support, Salary: 6391.0, Email: hassan.shaker@example.com
# ID: 85, Name: Khaled Sobhy, Position: Product Manager, Salary: 12044.0, Email: khaled.sobhy@example.com
# ID: 86, Name: Yasmin Shaker, Position: Graphic Designer, Salary: 14128.0, Email: yasmin.shaker@example.com
# ID: 87, Name: Omar Lotfy, Position: IT Support, Salary: 13008.0, Email: omar.lotfy@example.com
# ID: 88, Name: Mona Adel, Position: Content Writer, Salary: 10770.0, Email: mona.adel@example.com
# ID: 89, Name: Laila Shaker, Position: Quality Assurance, Salary: 5781.0, Email: laila.shaker@example.com
# ID: 90, Name: Ali Nabil, Position: Project Manager, Salary: 3663.0, Email: ali.nabil@example.com
# ID: 91, Name: Tamer Hassan, Position: Sales Executive, Salary: 5406.0, Email: tamer.hassan@example.com
# ID: 92, Name: Khaled Lotfy, Position: IT Support, Salary: 8987.0, Email: khaled.lotfy@example.com
# ID: 93, Name: Mona Adel, Position: Customer Support, Salary: 10902.0, Email: mona.adel@example.com
# ID: 94, Name: Hassan Lotfy, Position: Accountant, Salary: 11297.0, Email: hassan.lotfy@example.com
# ID: 95, Name: Huda Ali, Position: Software Engineer, Salary: 5876.0, Email: huda.ali@example.com
# ID: 96, Name: Sara Othman, Position: Data Analyst, Salary: 14161.0, Email: sara.othman@example.com
# ID: 97, Name: Laila Kamal, Position: Customer Support, Salary: 11126.0, Email: laila.kamal@example.com
# ID: 98, Name: Rami Farid, Position: Data Analyst, Salary: 11366.0, Email: rami.farid@example.com
# ID: 99, Name: Nora Lotfy, Position: Content Writer, Salary: 12098.0, Email: nora.lotfy@example.com
# ID: 100, Name: Nora Salem, Position: Product Manager, Salary: 12531.0, Email: nora.salem@example.com
# ID: 101, Name: Huda Fahmy, Position: IT Support, Salary: 14467.0, Email: huda.fahmy@example.com
# ID: 102, Name: Laila Hassan, Position: Operations Manager, Salary: 13026.0, Email: laila.hassan@example.com
# ID: 103, Name: Huda Ismail, Position: Business Analyst, Salary: 3906.0, Email: huda.ismail@example.com
# ID: 104, Name: Rami Tawfik, Position: HR Manager, Salary: 10362.0, Email: rami.tawfik@example.com
# ID: 105, Name: Salma Adel, Position: Business Analyst, Salary: 13595.0, Email: salma.adel@example.com
# ID: 106, Name: Rami Fahmy, Position: Data Analyst, Salary: 4318.0, Email: rami.fahmy@example.com
# ID: 107, Name: Mohamed Ismail, Position: Graphic Designer, Salary: 7704.0, Email: mohamed.ismail@example.com
# ID: 108, Name: Hassan Salem, Position: Customer Support, Salary: 4090.0, Email: hassan.salem@example.com
# ID: 109, Name: Hassan Salem, Position: Business Analyst, Salary: 5357.0, Email: hassan.salem@example.com
# ID: 110, Name: Laila Adel, Position: Data Analyst, Salary: 6116.0, Email: laila.adel@example.com
# ID: 111, Name: Hassan Ali, Position: IT Support, Salary: 4898.0, Email: hassan.ali@example.com
# ID: 112, Name: Amira Adel, Position: Project Manager, Salary: 11852.0, Email: amira.adel@example.com
# ID: 113, Name: Omar Shaker, Position: Business Analyst, Salary: 5667.0, Email: omar.shaker@example.com
# ID: 114, Name: Omar Shaker, Position: Customer Support, Salary: 10775.0, Email: omar.shaker@example.com
# ID: 115, Name: Rami Nabil, Position: Operations Manager, Salary: 11277.0, Email: rami.nabil@example.com
# ID: 116, Name: Tamer Sobhy, Position: Network Administrator, Salary: 5346.0, Email: tamer.sobhy@example.com
# ID: 117, Name: Rami Fahmy, Position: Content Writer, Salary: 9114.0, Email: rami.fahmy@example.com
# ID: 118, Name: Khaled Kamal, Position: Accountant, Salary: 4291.0, Email: khaled.kamal@example.com
# ID: 119, Name: Salma Hussein, Position: Project Manager, Salary: 4481.0, Email: salma.hussein@example.com
# ID: 120, Name: Salma Nabil, Position: Product Manager, Salary: 9457.0, Email: salma.nabil@example.com
# ID: 121, Name: Salma Nabil, Position: Network Administrator, Salary: 9258.0, Email: salma.nabil@example.com
# ID: 122, Name: Yasmin Lotfy, Position: Customer Support, Salary: 9580.0, Email: yasmin.lotfy@example.com
# ID: 123, Name: Yasmin Ismail, Position: Customer Support, Salary: 12532.0, Email: yasmin.ismail@example.com
# ID: 124, Name: Salma Tawfik, Position: Business Analyst, Salary: 9518.0, Email: salma.tawfik@example.com
# ID: 125, Name: Khaled Ismail, Position: Data Analyst, Salary: 7229.0, Email: khaled.ismail@example.com
# ID: 126, Name: Mohamed Fathy, Position: Project Manager, Salary: 11804.0, Email: mohamed.fathy@example.com
# ID: 127, Name: Huda Kamal, Position: Business Analyst, Salary: 5395.0, Email: huda.kamal@example.com
# ID: 128, Name: Yasmin Fathy, Position: Content Writer, Salary: 9552.0, Email: yasmin.fathy@example.com
# ID: 129, Name: Amira Lotfy, Position: Accountant, Salary: 5296.0, Email: amira.lotfy@example.com
# ID: 130, Name: Laila Farid, Position: Marketing Specialist, Salary: 3144.0, Email: laila.farid@example.com
# ID: 131, Name: Ali Farid, Position: Graphic Designer, Salary: 14321.0, Email: ali.farid@example.com
# ID: 132, Name: Khaled Hussein, Position: Graphic Designer, Salary: 11101.0, Email: khaled.hussein@example.com
# ID: 133, Name: Tamer Nabil, Position: Product Manager, Salary: 13345.0, Email: tamer.nabil@example.com
# ID: 134, Name: Sara Tawfik, Position: Marketing Specialist, Salary: 12743.0, Email: sara.tawfik@example.com
# ID: 135, Name: Khaled Tawfik, Position: Content Writer, Salary: 7009.0, Email: khaled.tawfik@example.com
# ID: 136, Name: Khaled Adel, Position: Content Writer, Salary: 4546.0, Email: khaled.adel@example.com
# ID: 137, Name: Mona Hussein, Position: Quality Assurance, Salary: 8603.0, Email: mona.hussein@example.com
# ID: 138, Name: Omar Farid, Position: Product Manager, Salary: 14654.0, Email: omar.farid@example.com
# ID: 139, Name: Rami Salem, Position: Content Writer, Salary: 9889.0, Email: rami.salem@example.com
# ID: 140, Name: Rami Othman, Position: Business Analyst, Salary: 7337.0, Email: rami.othman@example.com
# ID: 141, Name: Laila Fahmy, Position: HR Manager, Salary: 7523.0, Email: laila.fahmy@example.com
# ID: 142, Name: Hassan Shaker, Position: Accountant, Salary: 5747.0, Email: hassan.shaker@example.com
# ID: 143, Name: Yasmin Ismail, Position: Business Analyst, Salary: 8763.0, Email: yasmin.ismail@example.com
# ID: 144, Name: Mohamed Kamal, Position: Product Manager, Salary: 8354.0, Email: mohamed.kamal@example.com
# ID: 145, Name: Salma Salem, Position: Data Analyst, Salary: 7694.0, Email: salma.salem@example.com
# ID: 146, Name: Rami Adel, Position: Product Manager, Salary: 9873.0, Email: rami.adel@example.com
# ID: 147, Name: Laila Ismail, Position: Software Engineer, Salary: 7772.0, Email: laila.ismail@example.com
# ID: 148, Name: Salma Ismail, Position: Network Administrator, Salary: 3167.0, Email: salma.ismail@example.com
# ID: 149, Name: Yasmin Fathy, Position: Accountant, Salary: 9415.0, Email: yasmin.fathy@example.com
# ID: 150, Name: Tamer Ali, Position: Marketing Specialist, Salary: 10087.0, Email: tamer.ali@example.com
# ID: 151, Name: Laila Fathy, Position: Operations Manager, Salary: 12334.0, Email: laila.fathy@example.com
# ID: 152, Name: Mona Ismail, Position: Data Analyst, Salary: 3289.0, Email: mona.ismail@example.com
# ID: 153, Name: Mona Hussein, Position: Project Manager, Salary: 12619.0, Email: mona.hussein@example.com
# ID: 154, Name: Laila Ali, Position: Sales Executive, Salary: 4405.0, Email: laila.ali@example.com
# ID: 155, Name: Laila Fahmy, Position: Project Manager, Salary: 8431.0, Email: laila.fahmy@example.com
# ID: 156, Name: Mona Tawfik, Position: Sales Executive, Salary: 14981.0, Email: mona.tawfik@example.com
# ID: 157, Name: Ahmed Nabil, Position: Content Writer, Salary: 14217.0, Email: ahmed.nabil@example.com
# ID: 158, Name: Ahmed Othman, Position: IT Support, Salary: 13386.0, Email: ahmed.othman@example.com
# ID: 159, Name: Hassan Farid, Position: Product Manager, Salary: 9469.0, Email: hassan.farid@example.com
# ID: 160, Name: Salma Tawfik, Position: HR Manager, Salary: 14540.0, Email: salma.tawfik@example.com
# ID: 161, Name: Mona Nabil, Position: Sales Executive, Salary: 9585.0, Email: mona.nabil@example.com
# ID: 162, Name: Omar Ali, Position: Software Engineer, Salary: 12324.0, Email: omar.ali@example.com
# ID: 163, Name: Ali Othman, Position: Data Analyst, Salary: 8774.0, Email: ali.othman@example.com
# ID: 164, Name: Laila Shaker, Position: Software Engineer, Salary: 7102.0, Email: laila.shaker@example.com
# ID: 165, Name: Hassan Lotfy, Position: Product Manager, Salary: 6276.0, Email: hassan.lotfy@example.com
# ID: 166, Name: Hassan Fahmy, Position: Quality Assurance, Salary: 4570.0, Email: hassan.fahmy@example.com
# ID: 167, Name: Ahmed Nabil, Position: Customer Support, Salary: 5380.0, Email: ahmed.nabil@example.com
# ID: 168, Name: Ahmed Othman, Position: Data Analyst, Salary: 13531.0, Email: ahmed.othman@example.com
# ID: 169, Name: Salma Salem, Position: Product Manager, Salary: 14177.0, Email: salma.salem@example.com
# ID: 170, Name: Nora Ali, Position: Project Manager, Salary: 10742.0, Email: nora.ali@example.com
# ID: 171, Name: Mona Nabil, Position: Sales Executive, Salary: 8992.0, Email: mona.nabil@example.com
# ID: 172, Name: Omar Ali, Position: Product Manager, Salary: 13367.0, Email: omar.ali@example.com
# ID: 173, Name: Omar Othman, Position: Customer Support, Salary: 10718.0, Email: omar.othman@example.com
# ID: 174, Name: Huda Othman, Position: Content Writer, Salary: 12067.0, Email: huda.othman@example.com
# ID: 175, Name: Huda Ismail, Position: Quality Assurance, Salary: 9045.0, Email: huda.ismail@example.com
# ID: 176, Name: Amira Fathy, Position: Quality Assurance, Salary: 6552.0, Email: amira.fathy@example.com
# ID: 177, Name: Laila Fathy, Position: Accountant, Salary: 14115.0, Email: laila.fathy@example.com
# ID: 178, Name: Tamer Farid, Position: IT Support, Salary: 10261.0, Email: tamer.farid@example.com
# ID: 179, Name: Ahmed Farid, Position: Quality Assurance, Salary: 12860.0, Email: ahmed.farid@example.com
# ID: 180, Name: Ahmed Tawfik, Position: Graphic Designer, Salary: 13301.0, Email: ahmed.tawfik@example.com
# ID: 181, Name: Laila Hussein, Position: Network Administrator, Salary: 12212.0, Email: laila.hussein@example.com
# ID: 182, Name: Nora Sobhy, Position: Content Writer, Salary: 7630.0, Email: nora.sobhy@example.com
# ID: 183, Name: Rami Ali, Position: Operations Manager, Salary: 13614.0, Email: rami.ali@example.com
# ID: 184, Name: Nora Nabil, Position: Data Analyst, Salary: 5118.0, Email: nora.nabil@example.com
# ID: 185, Name: Hassan Sobhy, Position: Network Administrator, Salary: 14251.0, Email: hassan.sobhy@example.com
# ID: 186, Name: Hassan Hussein, Position: Project Manager, Salary: 10184.0, Email: hassan.hussein@example.com
# ID: 187, Name: Sara Hassan, Position: Network Administrator, Salary: 6926.0, Email: sara.hassan@example.com
# ID: 188, Name: Omar Tawfik, Position: Network Administrator, Salary: 4928.0, Email: omar.tawfik@example.com
# ID: 189, Name: Sara Othman, Position: Software Engineer, Salary: 10791.0, Email: sara.othman@example.com
# ID: 190, Name: Yasmin Adel, Position: Product Manager, Salary: 10325.0, Email: yasmin.adel@example.com
# ID: 191, Name: Sara Tawfik, Position: HR Manager, Salary: 7590.0, Email: sara.tawfik@example.com
# ID: 192, Name: Amira Adel, Position: Content Writer, Salary: 5726.0, Email: amira.adel@example.com
# ID: 193, Name: Nora Kamal, Position: Customer Support, Salary: 4664.0, Email: nora.kamal@example.com
# ID: 194, Name: Mohamed Fathy, Position: HR Manager, Salary: 4439.0, Email: mohamed.fathy@example.com
# ID: 195, Name: Khaled Hussein, Position: Sales Executive, Salary: 10367.0, Email: khaled.hussein@example.com
# ID: 196, Name: Laila Hussein, Position: Software Engineer, Salary: 5657.0, Email: laila.hussein@example.com
# ID: 197, Name: Mona Othman, Position: Customer Support, Salary: 10000.0, Email: mona.othman@example.com
# ID: 198, Name: Omar Fahmy, Position: Network Administrator, Salary: 5204.0, Email: omar.fahmy@example.com
# ID: 199, Name: Omar Adel, Position: Network Administrator, Salary: 14377.0, Email: omar.adel@example.com
# ID: 200, Name: Mohamed Hussein, Position: Data Analyst, Salary: 11391.0, Email: mohamed.hussein@example.com
# ID: 202, Name: marwan, Position: manger, Salary: 1e+40, Email: marwangasser600000000000000@gmail.com
#
# --- Employee Management System ---
# 1. Add Employee
# 2. Update Employee
# 3. Delete Employee
# 4. Search Employee
# 5. List Employees
# 6. Exit
# Enter your choice (1-6): 6
# Exiting the program. Goodbye!

# %%
# !git add .
# !git commit -m "Updated project"
# !git push origin main
# Out:
# [main dd644d8] Updated project
#  1 file changed, 326 insertions(+), 3 deletions(-)
# To https://github.com/Marwangasser1/Employee-Management-System.git
#    889d7dd..dd644d8  main -> main
